# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus

password = quote_plus("Anuj@7084")  # <-- your real password goes HERE, inside the quotes
engine = create_engine(f"postgresql://postgres:{password}@localhost:5432/ecommerce_db")  # <-- leave {password} exactly as-is here

master = pd.read_csv("../data/processed/master_ecommerce.csv")
rfm = pd.read_csv("../data/processed/rfm_segments.csv")

master.to_sql('orders_master', engine, if_exists='replace', index=False)
rfm.to_sql('rfm_segments', engine, if_exists='replace', index=False)

print("Tables loaded successfully!")
# Out:
# Tables loaded successfully!
